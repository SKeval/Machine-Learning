# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('housing_price_dataset.csv')

# %%
df.sample(5)
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 6920         1165         4          3        Rural       1990  197505.750771
# 42642        2275         3          3        Urban       1991  244428.518583
# 41075        1838         2          2        Rural       2011  192215.908464
# 48464        2211         5          3        Rural       1987  177264.049542
# 39488        2722         4          2        Rural       1968  309709.608828

# %%
df.shape
# Out:
# (50000, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SquareFeet    50000 non-null  int64
#  1   Bedrooms      50000 non-null  int64
#  2   Bathrooms     50000 non-null  int64
#  3   Neighborhood  50000 non-null  object
#  4   YearBuilt     50000 non-null  int64
#  5   Price         50000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# SquareFeet      0
# Bedrooms        0
# Bathrooms       0
# Neighborhood    0
# YearBuilt       0
# Price           0
# dtype: int64

# %%
df.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)['Price']
# Out:
# SquareFeet    0.750720
# Bedrooms      0.072624
# Bathrooms     0.028418
# YearBuilt    -0.002288
# Price         1.000000
# Name: Price, dtype: float64

# %% [markdown]
# # EDA

# %%
df_random = df.sample(10000)

# %% [markdown]
# ## Uni-Variant Analysis
# ### Categorical Data

# %%
sns.countplot(x='Neighborhood', data=df)
# Out:
# <Axes: xlabel='Neighborhood', ylabel='count'>

# %%
df['Neighborhood'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Numerical Data

# %%
df['SquareFeet'].describe()
# Out:
# count    50000.000000
# mean      2006.374680
# std        575.513241
# min       1000.000000
# 25%       1513.000000
# 50%       2007.000000
# 75%       2506.000000
# max       2999.000000
# Name: SquareFeet, dtype: float64

# %%
df['SquareFeet'].plot(kind='hist', bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['SquareFeet'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['SquareFeet'].skew()
# Out:
# np.float64(-0.011161817099369262)

# %%
df['SquareFeet'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Bedrooms'].describe()
# Out:
# count    50000.000000
# mean         3.498700
# std          1.116326
# min          2.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Bedrooms, dtype: float64

# %%
df['Bedrooms'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Bedrooms'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Bedrooms'].skew()
# Out:
# np.float64(0.004640350313677791)

# %%
df['Bedrooms'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Bathrooms'].describe()
# Out:
# count    50000.000000
# mean         1.995420
# std          0.815851
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          3.000000
# Name: Bathrooms, dtype: float64

# %%
df['Bathrooms'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Bathrooms'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Bathrooms'].skew()
# Out:
# np.float64(0.008407664728520576)

# %%
df['Bathrooms'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['YearBuilt'].describe()
# Out:
# count    50000.000000
# mean      1985.404420
# std         20.719377
# min       1950.000000
# 25%       1967.000000
# 50%       1985.000000
# 75%       2003.000000
# max       2021.000000
# Name: YearBuilt, dtype: float64

# %%
df['YearBuilt'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['YearBuilt'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['YearBuilt'].skew()
# Out:
# np.float64(0.00555654660638406)

# %%
df['YearBuilt'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Price'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Price'].skew()
# Out:
# np.float64(-0.008250544772666662)

# %%
df['Price'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## BiVariate Analysis
# ### Numerical - Numerical

# %%
df.sample(5)
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 45225        2182         3          2        Rural       1963  314088.459307
# 49229        2901         3          1        Urban       1969  342420.351205
# 3642         2489         2          1        Rural       1974  240502.159863
# 24307        2171         3          3        Urban       2011  282610.743093
# 6325         2504         3          3        Urban       2010  242087.443294

# %%
df_small = df.sample(100)
sns.scatterplot(x='Bedrooms',y='SquareFeet',data=df_small)
# Out:
# <Axes: xlabel='Bedrooms', ylabel='SquareFeet'>

# %%
sns.lmplot(x='Bathrooms',y='SquareFeet',data=df_small)

# %%
sns.barplot(x='Neighborhood', y='Price',data=df_small)    # X = Categorical, y = Numerical
# Out:
# <Axes: xlabel='Neighborhood', ylabel='Price'>

# %%
sns.barplot(x='Neighborhood', y='SquareFeet',data=df_small)    # X = Categorical, y = Numerical
# Out:
# <Axes: xlabel='Neighborhood', ylabel='SquareFeet'>

# %%
sns.barplot(x='Neighborhood', y='YearBuilt',data=df_small)    # X = Categorical, y = Numerical
# Out:
# <Axes: xlabel='Neighborhood', ylabel='YearBuilt'>

# %%
sns.boxplot(x='Neighborhood', y='YearBuilt',data=df_small)
# Out:
# <Axes: xlabel='Neighborhood', ylabel='YearBuilt'>

# %% [markdown]
# ## Feature Engg.
# ### Feature Scaling
#
# Square Feet column has minimum and maximum value so we use Minmax scalling

# %%
df['SquareFeet'].describe()
# Out:
# count    50000.000000
# mean      2006.374680
# std        575.513241
# min       1000.000000
# 25%       1513.000000
# 50%       2007.000000
# 75%       2506.000000
# max       2999.000000
# Name: SquareFeet, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(df.drop(columns=['Price']),df['Price'],test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(sparse_output=False, dtype=np.int32), ['Neighborhood']),
    ('num', MinMaxScaler(), ['SquareFeet', 'Bedrooms', 'Bathrooms', 'YearBuilt'])
], remainder='passthrough')

# %%
from sklearn.feature_selection import SelectKBest, chi2

feature_selector = SelectKBest(score_func=chi2, k=5)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# ### Create Pipeline

# %%
from sklearn.pipeline import Pipeline,make_pipeline

pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('feature_selector', feature_selector),
    ('model', model)
])

# %%
ytrain = np.array(ytrain).ravel()

# %%
print(ytrain.dtype)  # Should be int or float
print(np.isnan(ytrain).sum())  # Should be 0 (no NaNs)
xtrain.info
# Out:
# float64
# 0
# <bound method DataFrame.info of        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt
# 39087        2498         2          3        Rural       2021
# 30893        2380         5          3        Urban       1977
# 45278        2274         5          2        Urban       1957
# 16398        2215         5          1       Suburb       1977
# 13653        2078         2          3       Suburb       1962
# ...           ...       ...        ...          ...        ...
# 11284        2166         5          3       Suburb       1996
# 44732        2463         4          1        Urban       1953
# 38158        2812         4          2        Urban       2010
# 860          2188         3          1        Urban       1979
# 15795        2649         5          3        Rural       1953
#
# [40000 rows x 5 columns]>

# %%
ytrain = np.array(ytrain).astype(int).ravel()  # Convert to 1D integer array
ytest = np.array(ytest).astype(int).ravel()  # Convert to 1D integer array

# %%
ytrain
# Out:
# array([288178, 374155, 242571, ..., 248092, 132414, 288751])

# %%
model.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6028\32782139.py in ?()
# ----> 1 model.fit(xtrain, ytrain)
#
# c:\Users\keval\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\keval\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     597         n_jobs_ = self.n_jobs
#     598
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
# ...

# %%
print(xtrain.dtypes)  # Shows data types of each column
# Out:
# SquareFeet       int64
# Bedrooms         int64
# Bathrooms        int64
# Neighborhood    object
# YearBuilt        int64
# dtype: object

# %%
one = OneHotEncoder(sparse_output=False, dtype=np.int32)
one.fit(xtrain[['Neighborhood']])
xtn = one.transform(xtrain[['Neighborhood']])
xtt = one.transform(xtest[['Neighborhood']])

# %%
xtrain['Neighbor'] = np.argmax(one.transform(df.loc[xtrain.index, ['Neighborhood']]), axis=1)
xtest['Neighbor'] = np.argmax(one.transform(df.loc[xtest.index, ['Neighborhood']]), axis=1)

# %%
xtrain.info
# Out:
# <bound method DataFrame.info of        SquareFeet  Bedrooms  Bathrooms  YearBuilt  Neighbor
# 39087        2498         2          3       2021         0
# 30893        2380         5          3       1977         2
# 45278        2274         5          2       1957         2
# 16398        2215         5          1       1977         1
# 13653        2078         2          3       1962         1
# ...           ...       ...        ...        ...       ...
# 11284        2166         5          3       1996         1
# 44732        2463         4          1       1953         2
# 38158        2812         4          2       2010         2
# 860          2188         3          1       1979         2
# 15795        2649         5          3       1953         0
#
# [40000 rows x 5 columns]>

# %%
xtrain.drop(columns=['Neighborhood'],inplace=True)

# %%
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
xtest = xtest.drop(columns=['Neighborhood'])
ypred = model.predict(xtest)

# %%
r2 = model.score(xtest, ytest)

# %%
r2score = r2

# %%
r2score
# Out:
# 0.5754227007800532

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
mse = mean_squared_error(ytest, ypred)

# %%
mse
# Out:
# 2437053734.261331

# %%
mean_absolute_error(ytest, ypred)
# Out:
# 39433.362779435505

# %%
model.predict([[2294, 2, 1, 1996,2]])
# Out:
# c:\Users\keval\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([243236.28259307])

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
xtrain.head()
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt  Neighbor
# 39087        2498         2          3       2021         0
# 30893        2380         5          3       1977         2
# 45278        2274         5          2       1957         2
# 16398        2215         5          1       1977         1
# 13653        2078         2          3       1962         1
